# %% [markdown]
# # ResNet Failure Analysis Template
#
# 记录模型失败案例、假设、验证实验和结论。

# %% [markdown]
# ## 1. Failure Case 定义
# - 数据条件：
# - 模型：
# - 失败现象：
# - 可能原因：Optimization / Overfitting / Distribution Shift / Label Noise / Class Imbalance

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. 读取实验日志

# %%
# df = pd.read_csv('../outputs/logs/your_experiment.csv')
# df.head()

# %% [markdown]
# ## 3. 分析结论
# - 训练误差是否下降？
# - 验证误差是否上升？
# - 是否符合过拟合？
# - 如果 train error 本身很高，更可能是 optimization issue。
